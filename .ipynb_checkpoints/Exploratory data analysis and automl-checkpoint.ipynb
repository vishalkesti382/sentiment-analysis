# %%
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from autoviml.Auto_NLP import Auto_NLP

# %%
df = pd.read_csv('dataset_sa.csv', usecols=['text', 'label'])
# Out:
#   File "<ipython-input-11-3f0f1ea93a80>", line 1
#     df = pd.read_csv('dataset_sa.csv', usecols=['text', 'label'], usecols=['text', 'label'])
#                                                                  ^
# SyntaxError: keyword argument repeated

# %%
df.head()
# Out:
#    label  \
# 0      0
# 1      0
# 2      0
# 3      0
# 4     -1
#
#                                                                                 text
# 0                          Vinder Real Madrid Champions League for fjerde �r i tr�k?
# 1                                 Vinder Caroline Wozniacki en Grand Slam-turnering?
# 2  Vil Demokraterne i Repr�sentanternes Hus indlede en rigsretssag mod Donald Trump?
# 3                     Vi vil vinde," skriver han p� Twitter efter Pelosis udmelding.
# 4                Vi er n�dt til rent faktisk at g�re en forskel, sagde Donald Trump.

# %%
df.label.value_counts()
# Out:
#  0    72
# -2    55
# -1    37
#  1    25
#  2    16
# Name: label, dtype: int64

# %%
train, test = train_test_split(df, test_size = 0.25, random_state=1)

# %%
nlp_column = 'text'
target = 'label'

train_nlp, test_nlp, nlp_transform, predictions = Auto_NLP(nlp_column, train, test, target,
                                                          score_type='balanced_accuracy',
                                                          modeltype='Classification', top_num_features=100,
                                                          verbose = 2,
                                                          build_model=True)
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\Prajju\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\Prajju\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\gazetteers.zip.
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\Prajju\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\genesis.zip.
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\Prajju\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\Prajju\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\Prajju\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\movie_reviews.zip.
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\Prajju\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\names.zip.
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\Prajju\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\shakespeare.zip.
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\Prajju\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\Prajju\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\Prajju\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\twitter_samples.zip.
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\Prajju\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\omw.zip.
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\Prajju\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\Prajju\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\wordnet_ic.zip.
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\Prajju\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\Prajju\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\Prajju\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\Prajju\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\Prajju\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# Auto NLP processing on NLP Column: text
# Shape of Train Data: 153 rows
#     Shape of Test Data: 52 rows
#     Added 9 summary columns for counts of words and characters in each row
# Cleaning text in Train data for text column
#     Faster text processing using clean_text function, since top_num_features is below 300
#     Time Taken for Expanding emojis and abbreviations in data = 0 seconds
#         Time Taken for Processing text in data = 6 seconds
# Train data Text cleaning completed. Time taken = 13 seconds
#
# For target = label
#
#     For class = -2
# Top 200 n-grams
# : ['original', 'er', 'trump', 'det', 'af', 'der', 'amerikanske', 'r', 'han', 'donald', 'p', 'channel', 'den', 'men', 'blev', 'var', 'om', 'ikke', 'de', 'en', 'bliver', 'et', 'mod', 'pr', 'enhver', 'ved', 'st', 'alle', 'ville', 'kan', 'anklager', 'flere', 'comey', 'med', 'denne', 'har', 'meget', 'g', 'k', 'hurtigt', 'rt', 'sv', 'v', 'kommer', 'sig', 'hvis', 'inger', 'jberg', 'siger', 'learn', 'today', 'gelserne', 'hun', 'unders', 'vanskelige', 'donald trump', 'mod trump', 'comey der', 'sv rt', 'amerikanske pr', 'det er', 'today learn', 'inger st', 'st jberg', 'det amerikanske', 'g unders', 'gelserne vanskelige', 'hun ville', 'unders gelserne', 'vanskelige alle', 'ville g', 'inger st jberg', 'g unders gelserne', 'gelserne vanskelige alle', 'hun ville g', 'unders gelserne vanskelige', 'ville g unders']
#     Top n-grams that are most frequent in this class are: 77
#
#     For class = -1
# Top 200 n-grams
# : ['er', 'det', 'af', 'en', 'med', 'ikke', 'r', 'original', 'har', 'vil', 'der', 'den', 'learn', 'today', 'ogs', 'sig', 'g', 'jeg', 'som', 'bag', 'donald', 'de', 'ind', 'p', 'ud', 'f', 'angiveligt', 'trump', 'skal', 'dem', 'flere', 'rt', 'johnson', 'et', 'kunne', 'her', 'huawei', 'lge', 'v', 'republikanske', 'efter', 'skolen', 'pr', 'sident', 'var', 'today learn', 'det er', 'af dem', 'donald trump', 'ud af', 'det her', 'pr sident', 'er ikke', 'ikke f', 'det er ikke']
#     Top n-grams that are most frequent in this class are: 55
#
#     For class = 0
# Top 200 n-grams
# : ['er', 'det', 'en', 'de', 'af', 'et', 'original', 'r', 'den', 'p', 'vil', 'som', 'learn', 'today', 'der', 'usa', 'med', 'om', 'vinder', 'ikke', 'trump', 'han', 'skriver', 'blive', 'k', 'pr', 'b', 'var', 'flyet', 'har', 'hun', 'stadig', 'bogen', 'l', 'sverige', 'donald', 'v', 'hus', 'repr', 'sentanternes', 'hvad', 'cowen', 'tyler', 'kan', 'nogen', 'kim', 'stopper', 'siger', 'komme', 'blandt', 'instrukt', 'eller', 'danmark', 'rt', 'verden', 'formand', 'schweiz', 'ja', 'ukraine', 'fra', 'efterforskningen', 'g', 'bedste', 'st', 'lge', 'amerikanske', 'tung', 'side', 'mange', 'samlet', 'tre', 'mere', 'krav', 'bliver', 'fremg', 'aftale', 'politisk', 'skal', 'ting', 'red', 'beg', 'fejl', 'today learn', 'det er', 'donald trump', 'af de', 'instrukt r', 'tyler cowen', 'de er', 'repr sentanternes', 'sentanternes hus', 'skriver han', 'vil der', 'et en', 'der er', 'var det', 'det fremg', 'fremg r', 'det var', 'aftale om', 'en politisk', 'politisk aftale', 'beg et', 'en fejl', 'kan beg', 'af usa', 'ikke hvad', 'repr sentanternes hus', 'det fremg r', 'en politisk aftale', 'politisk aftale om', 'beg et en', 'et en fejl', 'kan beg et']
#     Top n-grams that are most frequent in this class are: 114
#
#     For class = 1
# Top 200 n-grams
# : ['er', 'original', 'den', 'af', 'det', 'rige', 'vil', 'har', 'men', 'han', 'b', 'v', 'briterne', 'biden', 'f', 'ogs', 'p', 'de', 'r', 'boris', 'johnson', 'en', 'et', 'sig', 'b de', 'boris johnson', 'den rige', 'rige boris', 'den rige boris', 'rige boris johnson']
#     Top n-grams that are most frequent in this class are: 30
#
#     For class = 2
# Top 200 n-grams
# : ['f', 'en', 'er', 'det', 'der', 'v', 'pr', 'var', 'men', 'r', 'har', 'trump', 'den', 'sident', 'siden', 'hertil', 'hvad', 'lad', 'mange', 'rtier', 'se', 'sker', 'taget', 'pr sident', 'der sker', 'det har', 'har taget', 'hertil lad', 'hvad der', 'lad se', 'mange rtier', 'rtier hertil', 'se hvad', 'taget mange', 'det har taget', 'har taget mange', 'hertil lad se', 'hvad der sker', 'lad se hvad', 'mange rtier hertil', 'rtier hertil lad', 'se hvad der', 'taget mange rtier']
#     Top n-grams that are most frequent in this class are: 43
# Time Taken = 0 seconds
# ##################    THIS IS FOR BUILD_MODEL = TRUE           #################
# Building Model and Pipeline for NLP column = text. This will take time...
#        Class  -> Counts -> Percent
#           -2:      37  ->   24.2%
#           -1:      31  ->   20.3%
#            0:      56  ->   36.6%
#            1:      17  ->   11.1%
#            2:      12  ->    7.8%
#     Selected the maximum number of features limit = 292
# Performing RandomizedSearchCV across 30 params. Optimizing for accuracy
#     Using train data = (137,) and Cross Validation data = (16,)
# Using a Calibrated Classifier in this Multi_Classification dataset to improve results...
# Since top_num_features = 100, Multinomial NB model selected. If you need different model, increase it >= 300.
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 238; got 285. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 212; got 285. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 217; got 285. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 227; got 285. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 238; got 285. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 237; got 280. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 211; got 280. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 217; got 280. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 226; got 280. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 238; got 280. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 238; got 276. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 212; got 276. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 217; got 276. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 227; got 276. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 238; got 276. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 212; got 230. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 217; got 230. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 227; got 230. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 229; got 240. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 204; got 240. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 207; got 240. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 218; got 240. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 229; got 240. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
# ...
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 217; got 248. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 227; got 248. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 238; got 248. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 238; got 249. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 212; got 249. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 217; got 249. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 227; got 249. Use k='all' to return all features.
#
#   FitFailedWarning)
# C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 296, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Prajju\Anaconda3\lib\site-packages\joblib\memory.py", line 355, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 352, in fit
#     self._check_params(X, y)
#   File "C:\Users\Prajju\AppData\Roaming\Python\Python37\site-packages\sklearn\feature_selection\_univariate_selection.py", line 525, in _check_params
#     % (X.shape[1], self.k))
# ValueError: k should be >=0, <= n_features = 238; got 249. Use k='all' to return all features.
#
#   FitFailedWarning)
# Training completed. Time taken for training = 0.1 minutes
# Best Params of NLP pipeline are: {'multinomialnb__alpha': 0.10554000904938199, 'selectkbest__k': 122, 'tfidfvectorizer__binary': True, 'tfidfvectorizer__encoding': 'latin-1', 'tfidfvectorizer__max_df': 0.5398062156658355}
# <style>.container { width:95% !important; }</style>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-ef725dd92db9> in <module>
#       6                                                           modeltype='Classification', top_num_features=100,
#       7                                                           verbose = 2,
# ----> 8                                                           build_model=True)
#
# ~\Anaconda3\lib\site-packages\autoviml\Auto_NLP.py in Auto_NLP(nlp_column, train, test, target, score_type, modeltype, top_num_features, verbose, build_model)
#    1599             print(classification_report(y_test.values, y_pred, target_names=target))
#    1600         else:
# -> 1601             plot_confusion_matrix(y_test, y_pred, model_name)
#    1602             plot_classification_matrix(y_test, y_pred, model_name)
#    1603     ### Train the Pipeline on the full data set here ###########################
#
# ~\Anaconda3\lib\site-packages\autoviml\Auto_NLP.py in plot_confusion_matrix(y_test, y_pred, model_name)
#    1828     sns.heatmap(cm_df,
#    1829                 center=0,
# -> 1830                 cmap=sns.diverging_palette(220, 15, as_cmap=True),
#    1831                 annot=True,
#    1832                 fmt='g')
#
# ~\Anaconda3\lib\site-packages\seaborn\palettes.py in diverging_palette(h_neg, h_pos, s, l, sep, n, center, as_cmap)
#     742     """
#     743     palfunc = dark_palette if center == "dark" else light_palette
# --> 744     neg = palfunc((h_neg, s, l), 128 - (sep / 2), reverse=True, input="husl")
#     745     pos = palfunc((h_pos, s, l), 128 - (sep / 2), input="husl")
#     746     midpoint = dict(light=[(.95, .95, .95, 1.)],
#
# ~\Anaconda3\lib\site-packages\seaborn\palettes.py in light_palette(color, n_colors, reverse, as_cmap, input)
#     639     light = set_hls_values(color, l=.95)  # noqa
#     640     colors = [color, light] if reverse else [light, color]
# --> 641     return blend_palette(colors, n_colors, as_cmap)
#     642
#     643
#
# ~\Anaconda3\lib\site-packages\seaborn\palettes.py in blend_palette(colors, n_colors, as_cmap, input)
#     775     pal = mpl.colors.LinearSegmentedColormap.from_list(name, colors)
#     776     if not as_cmap:
# --> 777         pal = _ColorPalette(pal(np.linspace(0, 1, n_colors)))
#     778     return pal
#     779
#
# <__array_function__ internals> in linspace(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\numpy\core\function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     118
#     119     """
# --> 120     num = operator.index(num)
#     121     if num < 0:
#     122         raise ValueError("Number of samples, %s, must be non-negative." % num)
#
# TypeError: 'float' object cannot be interpreted as an integer
